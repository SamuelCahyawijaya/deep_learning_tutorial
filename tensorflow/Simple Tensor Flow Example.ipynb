# %% [markdown]
# # Simple Tensor Flow Example
# Please go to https://www.tensorflow.org/api_docs/python/ for the package documentation

# %% [markdown]
# ## Load Common Package

# %%
import numpy as np

# %% [markdown]
# ## Load Tensor Flow Package

# %%
import tensorflow as tf

# %% [markdown]
# ## Basic Fully Connected Layer With Single Output
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg" width="50%"/>

# %% [markdown]
# ##### Generate Dummy Data

# %%
np.random.seed(0)

x_train = np.random.random((500, 3))
y_train = np.mean(x_train, axis=-1).reshape(500,1)
x_test = np.random.random((50, 3))
y_test = np.mean(x_test, axis=-1).reshape(50,1)

# %%
print("x_train.shape",x_train.shape)
print("y_train.shape",y_train.shape)
print("x_test.shape",x_test.shape)
print("y_test.shape",y_test.shape)
print("x_train[0]",x_train[0])
print("y_train[0]",y_train[0])
print("x_test[0]",x_test[0])
print("y_test[0]",y_test[0])
# Out:
# x_train.shape (500, 3)
# y_train.shape (500, 1)
# x_test.shape (50, 3)
# y_test.shape (50, 1)
# x_train[0] [ 0.5488135   0.71518937  0.60276338]
# y_train[0] [ 0.62225542]
# x_test[0] [ 0.44679332  0.83699037  0.22182403]
# y_test[0] [ 0.50186924]

# %% [markdown]
# ##### Initialize Model

# %%
# Define input & output node
X = tf.placeholder(tf.float32, shape=[None, 3])
y = tf.placeholder(tf.float32, shape=[None, 1])

# Define hidden layers parameters
w_1 = tf.Variable(tf.random_normal([3, 4], stddev=0.1))
w_2 = tf.Variable(tf.random_normal([4, 4], stddev=0.1))
w_3 = tf.Variable(tf.random_normal([4, 4], stddev=0.1))
w_4 = tf.Variable(tf.random_normal([4, 4], stddev=0.1))
w_5 = tf.Variable(tf.random_normal([4, 4], stddev=0.1))
w_6 = tf.Variable(tf.random_normal([4, 1], stddev=0.1))

b_1 = tf.Variable(tf.random_normal([4], stddev=0.5))
b_2 = tf.Variable(tf.random_normal([4], stddev=0.5))
b_3 =  tf.Variable(tf.random_normal([4], stddev=0.5))
b_4 = tf.Variable(tf.random_normal([4], stddev=0.5))
b_5 =  tf.Variable(tf.random_normal([4], stddev=0.5))
b_6 =  tf.Variable(tf.random_normal([1], stddev=0.5))

# Forward propagation
h_1    = tf.nn.relu(tf.add(tf.matmul(X, w_1), b_1))
h_2    = tf.nn.relu(tf.add(tf.matmul(h_1, w_2), b_2))
h_3    = tf.nn.relu(tf.add(tf.matmul(h_2, w_3), b_3))
h_4    = tf.nn.relu(tf.add(tf.matmul(h_3, w_4), b_4))
h_5    = tf.nn.relu(tf.add(tf.matmul(h_4, w_5), b_5))
yhat   = tf.nn.tanh(tf.add(tf.matmul(h_5, w_6), b_6))

# %%
# Backward propagation
cost      = tf.square(tf.subtract(y, yhat))
optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)

# %% [markdown]
# ##### Initialize Tensor Flow Session

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %% [markdown]
# ##### Train & Evaluate Model

# %%
batch_size = 50
steps = int(np.ceil(x_train.shape[0] / batch_size))

for epoch in range(200):
    # Train with each example
    for i in range(steps):
        sess.run(optimizer, feed_dict={X: x_train[i*batch_size:(i+1)*batch_size], y: y_train[i*batch_size:(i+1)*batch_size]})

    predict_train = sess.run(yhat, feed_dict={X: x_train, y: y_train})
    predict_test = sess.run(yhat, feed_dict={X: x_test, y: y_test})
    
    train_mae = np.mean(abs(y_train - predict_train))
    test_mae  = np.mean(abs(y_test - predict_test))

    print("Epoch = %d, train mae = %.5f, test mae = %.5f"
          % (epoch + 1, train_mae, test_mae))
    
print("y_train[0:5], predict_train[0:5]")
for i in range(5):
    print(y_train[i], predict_train[i])
    
print("y_test[0:5], predict_test[0:5]")
for i in range(5):
    print(y_test[i], predict_test[i])
# Out:
# Epoch = 1, train mae = 0.23166, test mae = 0.28204
# Epoch = 2, train mae = 0.21957, test mae = 0.26955
# Epoch = 3, train mae = 0.20968, test mae = 0.25881
# Epoch = 4, train mae = 0.20154, test mae = 0.25030
# Epoch = 5, train mae = 0.19524, test mae = 0.24351
# Epoch = 6, train mae = 0.19001, test mae = 0.23765
# Epoch = 7, train mae = 0.18530, test mae = 0.23318
# Epoch = 8, train mae = 0.18098, test mae = 0.22899
# Epoch = 9, train mae = 0.17704, test mae = 0.22489
# Epoch = 10, train mae = 0.17331, test mae = 0.22083
# Epoch = 11, train mae = 0.16978, test mae = 0.21675
# Epoch = 12, train mae = 0.16642, test mae = 0.21292
# Epoch = 13, train mae = 0.16335, test mae = 0.20938
# Epoch = 14, train mae = 0.16053, test mae = 0.20614
# Epoch = 15, train mae = 0.15795, test mae = 0.20286
# Epoch = 16, train mae = 0.15560, test mae = 0.19957
# Epoch = 17, train mae = 0.15353, test mae = 0.19662
# Epoch = 18, train mae = 0.15165, test mae = 0.19372
# Epoch = 19, train mae = 0.14994, test mae = 0.19091
# Epoch = 20, train mae = 0.14851, test mae = 0.18831
# Epoch = 21, train mae = 0.14734, test mae = 0.18624
# Epoch = 22, train mae = 0.14640, test mae = 0.18467
# Epoch = 23, train mae = 0.14571, test mae = 0.18330
# Epoch = 24, train mae = 0.14525, test mae = 0.18212
# Epoch = 25, train mae = 0.14491, test mae = 0.18111
# Epoch = 26, train mae = 0.14470, test mae = 0.18029
# Epoch = 27, train mae = 0.14457, test mae = 0.17966
# Epoch = 28, train mae = 0.14452, test mae = 0.17923
# Epoch = 29, train mae = 0.14451, test mae = 0.17890
# Epoch = 30, train mae = 0.14452, test mae = 0.17866
# Epoch = 31, train mae = 0.14453, test mae = 0.17849
# Epoch = 32, train mae = 0.14455, test mae = 0.17836
# Epoch = 33, train mae = 0.14456, test mae = 0.17828
# Epoch = 34, train mae = 0.14456, test mae = 0.17822
# Epoch = 35, train mae = 0.14456, test mae = 0.17819
# Epoch = 36, train mae = 0.14457, test mae = 0.17816
# Epoch = 37, train mae = 0.14457, test mae = 0.17814
# Epoch = 38, train mae = 0.14457, test mae = 0.17813
# Epoch = 39, train mae = 0.14456, test mae = 0.17811
# Epoch = 40, train mae = 0.14456, test mae = 0.17810
# Epoch = 41, train mae = 0.14455, test mae = 0.17808
# Epoch = 42, train mae = 0.14455, test mae = 0.17806
# Epoch = 43, train mae = 0.14454, test mae = 0.17803
# Epoch = 44, train mae = 0.14452, test mae = 0.17799
# Epoch = 45, train mae = 0.14450, test mae = 0.17794
# Epoch = 46, train mae = 0.14447, test mae = 0.17786
# Epoch = 47, train mae = 0.14443, test mae = 0.17775
# Epoch = 48, train mae = 0.14437, test mae = 0.17761
# Epoch = 49, train mae = 0.14429, test mae = 0.17741
# Epoch = 50, train mae = 0.14416, test mae = 0.17712
# Epoch = 51, train mae = 0.14397, test mae = 0.17672
# Epoch = 52, train mae = 0.14369, test mae = 0.17618
# Epoch = 53, train mae = 0.14330, test mae = 0.17542
# Epoch = 54, train mae = 0.14275, test mae = 0.17439
# Epoch = 55, train mae = 0.14200, test mae = 0.17302
# Epoch = 56, train mae = 0.14102, test mae = 0.17126
# Epoch = 57, train mae = 0.13976, test mae = 0.16909
# Epoch = 58, train mae = 0.13818, test mae = 0.16646
# Epoch = 59, train mae = 0.13626, test mae = 0.16338
# Epoch = 60, train mae = 0.13420, test mae = 0.16039
# Epoch = 61, train mae = 0.13195, test mae = 0.15752
# Epoch = 62, train mae = 0.12939, test mae = 0.15412
# Epoch = 63, train mae = 0.12641, test mae = 0.14985
# Epoch = 64, train mae = 0.12303, test mae = 0.14491
# Epoch = 65, train mae = 0.11926, test mae = 0.13966
# Epoch = 66, train mae = 0.11501, test mae = 0.13407
# Epoch = 67, train mae = 0.11021, test mae = 0.12795
# Epoch = 68, train mae = 0.10481, test mae = 0.12111
# Epoch = 69, train mae = 0.09872, test mae = 0.11359
# Epoch = 70, train mae = 0.09172, test mae = 0.10526
# Epoch = 71, train mae = 0.08361, test mae = 0.09599
# Epoch = 72, train mae = 0.07452, test mae = 0.08535
# Epoch = 73, train mae = 0.06468, test mae = 0.07370
# Epoch = 74, train mae = 0.05627, test mae = 0.06282
# Epoch = 75, train mae = 0.04863, test mae = 0.05370
# Epoch = 76, train mae = 0.04189, test mae = 0.04604
# Epoch = 77, train mae = 0.03678, test mae = 0.03951
# Epoch = 78, train mae = 0.03255, test mae = 0.03495
# Epoch = 79, train mae = 0.02993, test mae = 0.03196
# Epoch = 80, train mae = 0.02882, test mae = 0.03025
# Epoch = 81, train mae = 0.02822, test mae = 0.02921
# Epoch = 82, train mae = 0.02777, test mae = 0.02859
# Epoch = 83, train mae = 0.02740, test mae = 0.02823
# Epoch = 84, train mae = 0.02709, test mae = 0.02797
# Epoch = 85, train mae = 0.02684, test mae = 0.02777
# Epoch = 86, train mae = 0.02657, test mae = 0.02758
# Epoch = 87, train mae = 0.02632, test mae = 0.02740
# Epoch = 88, train mae = 0.02609, test mae = 0.02725
# Epoch = 89, train mae = 0.02579, test mae = 0.02708
# Epoch = 90, train mae = 0.02557, test mae = 0.02695
# Epoch = 91, train mae = 0.02533, test mae = 0.02682
# Epoch = 92, train mae = 0.02507, test mae = 0.02669
# Epoch = 93, train mae = 0.02487, test mae = 0.02664
# Epoch = 94, train mae = 0.02464, test mae = 0.02659
# Epoch = 95, train mae = 0.02442, test mae = 0.02658
# Epoch = 96, train mae = 0.02421, test mae = 0.02653
# Epoch = 97, train mae = 0.02401, test mae = 0.02643
# Epoch = 98, train mae = 0.02380, test mae = 0.02630
# Epoch = 99, train mae = 0.02360, test mae = 0.02616
# Epoch = 100, train mae = 0.02345, test mae = 0.02600
# Epoch = 101, train mae = 0.02331, test mae = 0.02585
# Epoch = 102, train mae = 0.02313, test mae = 0.02569
# Epoch = 103, train mae = 0.02291, test mae = 0.02553
# Epoch = 104, train mae = 0.02270, test mae = 0.02537
# Epoch = 105, train mae = 0.02251, test mae = 0.02521
# Epoch = 106, train mae = 0.02232, test mae = 0.02506
# Epoch = 107, train mae = 0.02215, test mae = 0.02492
# Epoch = 108, train mae = 0.02199, test mae = 0.02479
# Epoch = 109, train mae = 0.02181, test mae = 0.02465
# Epoch = 110, train mae = 0.02165, test mae = 0.02451
# Epoch = 111, train mae = 0.02144, test mae = 0.02436
# Epoch = 112, train mae = 0.02128, test mae = 0.02422
# Epoch = 113, train mae = 0.02111, test mae = 0.02404
# Epoch = 114, train mae = 0.02096, test mae = 0.02388
# Epoch = 115, train mae = 0.02082, test mae = 0.02372
# Epoch = 116, train mae = 0.02065, test mae = 0.02354
# Epoch = 117, train mae = 0.02051, test mae = 0.02336
# Epoch = 118, train mae = 0.02037, test mae = 0.02318
# Epoch = 119, train mae = 0.02025, test mae = 0.02301
# Epoch = 120, train mae = 0.02013, test mae = 0.02290
# Epoch = 121, train mae = 0.02002, test mae = 0.02279
# Epoch = 122, train mae = 0.01991, test mae = 0.02268
# Epoch = 123, train mae = 0.01981, test mae = 0.02257
# Epoch = 124, train mae = 0.01968, test mae = 0.02245
# Epoch = 125, train mae = 0.01951, test mae = 0.02237
# Epoch = 126, train mae = 0.01938, test mae = 0.02229
# Epoch = 127, train mae = 0.01925, test mae = 0.02223
# Epoch = 128, train mae = 0.01915, test mae = 0.02218
# Epoch = 129, train mae = 0.01905, test mae = 0.02212
# Epoch = 130, train mae = 0.01892, test mae = 0.02207
# Epoch = 131, train mae = 0.01882, test mae = 0.02202
# Epoch = 132, train mae = 0.01873, test mae = 0.02197
# Epoch = 133, train mae = 0.01864, test mae = 0.02192
# Epoch = 134, train mae = 0.01856, test mae = 0.02188
# Epoch = 135, train mae = 0.01848, test mae = 0.02184
# Epoch = 136, train mae = 0.01840, test mae = 0.02180
# Epoch = 137, train mae = 0.01835, test mae = 0.02175
# Epoch = 138, train mae = 0.01830, test mae = 0.02171
# Epoch = 139, train mae = 0.01824, test mae = 0.02167
# Epoch = 140, train mae = 0.01820, test mae = 0.02164
# Epoch = 141, train mae = 0.01819, test mae = 0.02158
# Epoch = 142, train mae = 0.01810, test mae = 0.02155
# Epoch = 143, train mae = 0.01805, test mae = 0.02151
# Epoch = 144, train mae = 0.01799, test mae = 0.02147
# Epoch = 145, train mae = 0.01796, test mae = 0.02144
# Epoch = 146, train mae = 0.01793, test mae = 0.02141
# Epoch = 147, train mae = 0.01791, test mae = 0.02137
# Epoch = 148, train mae = 0.01792, test mae = 0.02133
# Epoch = 149, train mae = 0.01787, test mae = 0.02130
# Epoch = 150, train mae = 0.01786, test mae = 0.02126
# Epoch = 151, train mae = 0.01783, test mae = 0.02123
# Epoch = 152, train mae = 0.01782, test mae = 0.02120
# Epoch = 153, train mae = 0.01780, test mae = 0.02117
# Epoch = 154, train mae = 0.01779, test mae = 0.02114
# Epoch = 155, train mae = 0.01778, test mae = 0.02111
# Epoch = 156, train mae = 0.01775, test mae = 0.02108
# Epoch = 157, train mae = 0.01774, test mae = 0.02105
# Epoch = 158, train mae = 0.01774, test mae = 0.02102
# Epoch = 159, train mae = 0.01771, test mae = 0.02099
# Epoch = 160, train mae = 0.01770, test mae = 0.02095
# Epoch = 161, train mae = 0.01768, test mae = 0.02090
# Epoch = 162, train mae = 0.01767, test mae = 0.02086
# Epoch = 163, train mae = 0.01767, test mae = 0.02082
# Epoch = 164, train mae = 0.01767, test mae = 0.02078
# Epoch = 165, train mae = 0.01767, test mae = 0.02075
# Epoch = 166, train mae = 0.01769, test mae = 0.02070
# Epoch = 167, train mae = 0.01768, test mae = 0.02067
# Epoch = 168, train mae = 0.01769, test mae = 0.02062
# Epoch = 169, train mae = 0.01768, test mae = 0.02058
# Epoch = 170, train mae = 0.01768, test mae = 0.02053
# Epoch = 171, train mae = 0.01769, test mae = 0.02047
# Epoch = 172, train mae = 0.01767, test mae = 0.02042
# Epoch = 173, train mae = 0.01769, test mae = 0.02037
# Epoch = 174, train mae = 0.01768, test mae = 0.02033
# Epoch = 175, train mae = 0.01771, test mae = 0.02028
# Epoch = 176, train mae = 0.01768, test mae = 0.02023
# Epoch = 177, train mae = 0.01768, test mae = 0.02019
# Epoch = 178, train mae = 0.01767, test mae = 0.02014
# Epoch = 179, train mae = 0.01767, test mae = 0.02010
# Epoch = 180, train mae = 0.01768, test mae = 0.02006
# Epoch = 181, train mae = 0.01772, test mae = 0.02002
# Epoch = 182, train mae = 0.01768, test mae = 0.01998
# Epoch = 183, train mae = 0.01768, test mae = 0.01994
# Epoch = 184, train mae = 0.01767, test mae = 0.01990
# Epoch = 185, train mae = 0.01767, test mae = 0.01987
# Epoch = 186, train mae = 0.01770, test mae = 0.01983
# Epoch = 187, train mae = 0.01767, test mae = 0.01979
# Epoch = 188, train mae = 0.01766, test mae = 0.01975
# Epoch = 189, train mae = 0.01766, test mae = 0.01971
# Epoch = 190, train mae = 0.01768, test mae = 0.01968
# Epoch = 191, train mae = 0.01767, test mae = 0.01966
# Epoch = 192, train mae = 0.01767, test mae = 0.01964
# Epoch = 193, train mae = 0.01767, test mae = 0.01962
# Epoch = 194, train mae = 0.01769, test mae = 0.01960
# Epoch = 195, train mae = 0.01768, test mae = 0.01958
# Epoch = 196, train mae = 0.01767, test mae = 0.01956
# Epoch = 197, train mae = 0.01767, test mae = 0.01954
# Epoch = 198, train mae = 0.01768, test mae = 0.01952
# Epoch = 199, train mae = 0.01768, test mae = 0.01951
# Epoch = 200, train mae = 0.01765, test mae = 0.01951
# y_train[0:5], predict_train[0:5]
# [ 0.62225542] [ 0.63238794]
# [ 0.53814403] [ 0.55470252]
# [ 0.76434099] [ 0.73967844]
# [ 0.56802049] [ 0.58342963]
# [ 0.52155909] [ 0.536901]
# y_test[0:5], predict_test[0:5]
# [ 0.50186924] [ 0.51689637]
# [ 0.69692623] [ 0.69234341]
# [ 0.77651315] [ 0.74741274]
# [ 0.27738522] [ 0.24560967]
# [ 0.59266056] [ 0.60663396]

# %% [markdown]
# ##### Close Session

# %%
sess.close()

# %% [markdown]
# ## Let's try in simpler way

# %% [markdown]
# ##### Initialize Model

# %%
# Define input & output node
X = tf.placeholder(tf.float32, shape=[None, 3])
y = tf.placeholder(tf.float32, shape=[None, 1])

# Forward propagation
h_1    = tf.contrib.layers.fully_connected(X, 4)
h_2    = tf.contrib.layers.fully_connected(h_1, 4)
h_3    = tf.contrib.layers.fully_connected(h_2, 4)
h_4    = tf.contrib.layers.fully_connected(h_3, 4)
h_5    = tf.contrib.layers.fully_connected(h_4, 4)
yhat   = tf.contrib.layers.fully_connected(h_5, 1, activation_fn=tf.nn.tanh)

# %%
# Backward propagation
cost      = tf.square(tf.subtract(y, yhat))
optimizer = tf.train.AdamOptimizer(0.01).minimize(cost)

# %% [markdown]
# ##### Initialize Tensor Flow Session

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %% [markdown]
# ##### Train & Evaluate Model

# %%
batch_size = 50
steps = int(np.ceil(x_train.shape[0] / batch_size))

for epoch in range(200):
    # Train with each example
    for i in range(steps):
        sess.run(optimizer, feed_dict={X: x_train[i*batch_size:(i+1)*batch_size], y: y_train[i*batch_size:(i+1)*batch_size]})

    predict_train = sess.run(yhat, feed_dict={X: x_train, y: y_train})
    predict_test = sess.run(yhat, feed_dict={X: x_test, y: y_test})
    
    train_mae = np.mean(abs(y_train - predict_train))
    test_mae  = np.mean(abs(y_test - predict_test))

    print("Epoch = %d, train mae = %.5f, test mae = %.5f"
          % (epoch + 1, train_mae, test_mae))
    
print("y_train[0:5], predict_train[0:5]")
for i in range(5):
    print(y_train[i], predict_train[i])
    
print("y_test[0:5], predict_test[0:5]")
for i in range(5):
    print(y_test[i], predict_test[i])
# Out:
# Epoch = 1, train mae = 0.20302, test mae = 0.25331
# Epoch = 2, train mae = 0.16555, test mae = 0.17094
# Epoch = 3, train mae = 0.15465, test mae = 0.17134
# Epoch = 4, train mae = 0.14576, test mae = 0.18365
# Epoch = 5, train mae = 0.14580, test mae = 0.18363
# Epoch = 6, train mae = 0.14504, test mae = 0.17703
# Epoch = 7, train mae = 0.14482, test mae = 0.17750
# Epoch = 8, train mae = 0.14455, test mae = 0.17947
# Epoch = 9, train mae = 0.14457, test mae = 0.17854
# Epoch = 10, train mae = 0.14465, test mae = 0.17803
# Epoch = 11, train mae = 0.14457, test mae = 0.17854
# Epoch = 12, train mae = 0.14457, test mae = 0.17849
# Epoch = 13, train mae = 0.14459, test mae = 0.17832
# Epoch = 14, train mae = 0.14457, test mae = 0.17843
# Epoch = 15, train mae = 0.14457, test mae = 0.17842
# Epoch = 16, train mae = 0.14457, test mae = 0.17838
# Epoch = 17, train mae = 0.14457, test mae = 0.17841
# Epoch = 18, train mae = 0.14456, test mae = 0.17840
# Epoch = 19, train mae = 0.14456, test mae = 0.17839
# Epoch = 20, train mae = 0.14456, test mae = 0.17840
# Epoch = 21, train mae = 0.14455, test mae = 0.17839
# Epoch = 22, train mae = 0.14454, test mae = 0.17839
# Epoch = 23, train mae = 0.14453, test mae = 0.17839
# Epoch = 24, train mae = 0.14450, test mae = 0.17837
# Epoch = 25, train mae = 0.14446, test mae = 0.17835
# Epoch = 26, train mae = 0.14437, test mae = 0.17827
# Epoch = 27, train mae = 0.14410, test mae = 0.17784
# Epoch = 28, train mae = 0.14331, test mae = 0.17650
# Epoch = 29, train mae = 0.14073, test mae = 0.17304
# Epoch = 30, train mae = 0.12971, test mae = 0.15618
# Epoch = 31, train mae = 0.08845, test mae = 0.10251
# Epoch = 32, train mae = 0.03584, test mae = 0.02686
# Epoch = 33, train mae = 0.02622, test mae = 0.02632
# Epoch = 34, train mae = 0.02030, test mae = 0.02643
# Epoch = 35, train mae = 0.01313, test mae = 0.01828
# Epoch = 36, train mae = 0.01340, test mae = 0.01645
# Epoch = 37, train mae = 0.01139, test mae = 0.01480
# Epoch = 38, train mae = 0.01076, test mae = 0.01449
# Epoch = 39, train mae = 0.00928, test mae = 0.01379
# Epoch = 40, train mae = 0.00907, test mae = 0.01332
# Epoch = 41, train mae = 0.00875, test mae = 0.01282
# Epoch = 42, train mae = 0.00832, test mae = 0.01233
# Epoch = 43, train mae = 0.00813, test mae = 0.01197
# Epoch = 44, train mae = 0.00791, test mae = 0.01167
# Epoch = 45, train mae = 0.00765, test mae = 0.01134
# Epoch = 46, train mae = 0.00740, test mae = 0.01101
# Epoch = 47, train mae = 0.00722, test mae = 0.01072
# Epoch = 48, train mae = 0.00706, test mae = 0.01045
# Epoch = 49, train mae = 0.00683, test mae = 0.01013
# Epoch = 50, train mae = 0.00665, test mae = 0.00985
# Epoch = 51, train mae = 0.00651, test mae = 0.00960
# Epoch = 52, train mae = 0.00635, test mae = 0.00934
# Epoch = 53, train mae = 0.00620, test mae = 0.00912
# Epoch = 54, train mae = 0.00605, test mae = 0.00892
# Epoch = 55, train mae = 0.00592, test mae = 0.00874
# Epoch = 56, train mae = 0.00582, test mae = 0.00859
# Epoch = 57, train mae = 0.00572, test mae = 0.00844
# Epoch = 58, train mae = 0.00562, test mae = 0.00832
# Epoch = 59, train mae = 0.00552, test mae = 0.00817
# Epoch = 60, train mae = 0.00544, test mae = 0.00803
# Epoch = 61, train mae = 0.00535, test mae = 0.00787
# Epoch = 62, train mae = 0.00525, test mae = 0.00771
# Epoch = 63, train mae = 0.00519, test mae = 0.00756
# Epoch = 64, train mae = 0.00512, test mae = 0.00740
# Epoch = 65, train mae = 0.00504, test mae = 0.00726
# Epoch = 66, train mae = 0.00499, test mae = 0.00712
# Epoch = 67, train mae = 0.00495, test mae = 0.00706
# Epoch = 68, train mae = 0.00488, test mae = 0.00686
# Epoch = 69, train mae = 0.00484, test mae = 0.00672
# Epoch = 70, train mae = 0.00477, test mae = 0.00660
# Epoch = 71, train mae = 0.00474, test mae = 0.00648
# Epoch = 72, train mae = 0.00469, test mae = 0.00632
# Epoch = 73, train mae = 0.00462, test mae = 0.00617
# Epoch = 74, train mae = 0.00464, test mae = 0.00625
# Epoch = 75, train mae = 0.00462, test mae = 0.00618
# Epoch = 76, train mae = 0.00456, test mae = 0.00604
# Epoch = 77, train mae = 0.00453, test mae = 0.00594
# Epoch = 78, train mae = 0.00448, test mae = 0.00580
# Epoch = 79, train mae = 0.00445, test mae = 0.00570
# Epoch = 80, train mae = 0.00440, test mae = 0.00560
# Epoch = 81, train mae = 0.00438, test mae = 0.00553
# Epoch = 82, train mae = 0.00433, test mae = 0.00544
# Epoch = 83, train mae = 0.00431, test mae = 0.00540
# Epoch = 84, train mae = 0.00427, test mae = 0.00530
# Epoch = 85, train mae = 0.00423, test mae = 0.00519
# Epoch = 86, train mae = 0.00421, test mae = 0.00511
# Epoch = 87, train mae = 0.00417, test mae = 0.00499
# Epoch = 88, train mae = 0.00413, test mae = 0.00490
# Epoch = 89, train mae = 0.00411, test mae = 0.00486
# Epoch = 90, train mae = 0.00409, test mae = 0.00481
# Epoch = 91, train mae = 0.00406, test mae = 0.00475
# Epoch = 92, train mae = 0.00403, test mae = 0.00468
# Epoch = 93, train mae = 0.00402, test mae = 0.00462
# Epoch = 94, train mae = 0.00399, test mae = 0.00453
# Epoch = 95, train mae = 0.00397, test mae = 0.00446
# Epoch = 96, train mae = 0.00395, test mae = 0.00440
# Epoch = 97, train mae = 0.00392, test mae = 0.00433
# Epoch = 98, train mae = 0.00390, test mae = 0.00424
# Epoch = 99, train mae = 0.00387, test mae = 0.00418
# Epoch = 100, train mae = 0.00385, test mae = 0.00413
# Epoch = 101, train mae = 0.00383, test mae = 0.00408
# Epoch = 102, train mae = 0.00382, test mae = 0.00405
# Epoch = 103, train mae = 0.00381, test mae = 0.00403
# Epoch = 104, train mae = 0.00380, test mae = 0.00401
# Epoch = 105, train mae = 0.00380, test mae = 0.00398
# Epoch = 106, train mae = 0.00380, test mae = 0.00395
# Epoch = 107, train mae = 0.00379, test mae = 0.00393
# Epoch = 108, train mae = 0.00378, test mae = 0.00392
# Epoch = 109, train mae = 0.00376, test mae = 0.00390
# Epoch = 110, train mae = 0.00374, test mae = 0.00388
# Epoch = 111, train mae = 0.00373, test mae = 0.00387
# Epoch = 112, train mae = 0.00371, test mae = 0.00385
# Epoch = 113, train mae = 0.00369, test mae = 0.00383
# Epoch = 114, train mae = 0.00368, test mae = 0.00381
# Epoch = 115, train mae = 0.00366, test mae = 0.00379
# Epoch = 116, train mae = 0.00365, test mae = 0.00376
# Epoch = 117, train mae = 0.00364, test mae = 0.00374
# Epoch = 118, train mae = 0.00363, test mae = 0.00373
# Epoch = 119, train mae = 0.00362, test mae = 0.00371
# Epoch = 120, train mae = 0.00361, test mae = 0.00369
# Epoch = 121, train mae = 0.00360, test mae = 0.00367
# Epoch = 122, train mae = 0.00358, test mae = 0.00365
# Epoch = 123, train mae = 0.00357, test mae = 0.00363
# Epoch = 124, train mae = 0.00356, test mae = 0.00361
# Epoch = 125, train mae = 0.00355, test mae = 0.00359
# Epoch = 126, train mae = 0.00354, test mae = 0.00357
# Epoch = 127, train mae = 0.00353, test mae = 0.00354
# Epoch = 128, train mae = 0.00352, test mae = 0.00352
# Epoch = 129, train mae = 0.00350, test mae = 0.00351
# Epoch = 130, train mae = 0.00349, test mae = 0.00350
# Epoch = 131, train mae = 0.00348, test mae = 0.00348
# Epoch = 132, train mae = 0.00347, test mae = 0.00347
# Epoch = 133, train mae = 0.00346, test mae = 0.00346
# Epoch = 134, train mae = 0.00345, test mae = 0.00344
# Epoch = 135, train mae = 0.00345, test mae = 0.00343
# Epoch = 136, train mae = 0.00344, test mae = 0.00341
# Epoch = 137, train mae = 0.00343, test mae = 0.00340
# Epoch = 138, train mae = 0.00342, test mae = 0.00339
# Epoch = 139, train mae = 0.00342, test mae = 0.00338
# Epoch = 140, train mae = 0.00341, test mae = 0.00338
# Epoch = 141, train mae = 0.00341, test mae = 0.00338
# Epoch = 142, train mae = 0.00340, test mae = 0.00338
# Epoch = 143, train mae = 0.00339, test mae = 0.00344
# Epoch = 144, train mae = 0.00339, test mae = 0.00338
# Epoch = 145, train mae = 0.00337, test mae = 0.00341
# Epoch = 146, train mae = 0.00336, test mae = 0.00336
# Epoch = 147, train mae = 0.00335, test mae = 0.00332
# Epoch = 148, train mae = 0.00335, test mae = 0.00329
# Epoch = 149, train mae = 0.00333, test mae = 0.00323
# Epoch = 150, train mae = 0.00333, test mae = 0.00320
# Epoch = 151, train mae = 0.00332, test mae = 0.00317
# Epoch = 152, train mae = 0.00331, test mae = 0.00314
# Epoch = 153, train mae = 0.00331, test mae = 0.00312
# Epoch = 154, train mae = 0.00330, test mae = 0.00309
# Epoch = 155, train mae = 0.00329, test mae = 0.00309
# Epoch = 156, train mae = 0.00329, test mae = 0.00304
# Epoch = 157, train mae = 0.00328, test mae = 0.00308
# Epoch = 158, train mae = 0.00328, test mae = 0.00303
# Epoch = 159, train mae = 0.00328, test mae = 0.00305
# Epoch = 160, train mae = 0.00328, test mae = 0.00302
# Epoch = 161, train mae = 0.00328, test mae = 0.00305
# Epoch = 162, train mae = 0.00327, test mae = 0.00301
# Epoch = 163, train mae = 0.00327, test mae = 0.00303
# Epoch = 164, train mae = 0.00327, test mae = 0.00302
# Epoch = 165, train mae = 0.00326, test mae = 0.00301
# Epoch = 166, train mae = 0.00327, test mae = 0.00304
# Epoch = 167, train mae = 0.00325, test mae = 0.00300
# Epoch = 168, train mae = 0.00326, test mae = 0.00302
# Epoch = 169, train mae = 0.00325, test mae = 0.00301
# Epoch = 170, train mae = 0.00326, test mae = 0.00300
# Epoch = 171, train mae = 0.00325, test mae = 0.00301
# Epoch = 172, train mae = 0.00325, test mae = 0.00296
# Epoch = 173, train mae = 0.00327, test mae = 0.00304
# Epoch = 174, train mae = 0.00324, test mae = 0.00297
# Epoch = 175, train mae = 0.00325, test mae = 0.00295
# Epoch = 176, train mae = 0.00325, test mae = 0.00296
# Epoch = 177, train mae = 0.00324, test mae = 0.00290
# Epoch = 178, train mae = 0.00324, test mae = 0.00292
# Epoch = 179, train mae = 0.00324, test mae = 0.00292
# Epoch = 180, train mae = 0.00324, test mae = 0.00290
# Epoch = 181, train mae = 0.00325, test mae = 0.00295
# Epoch = 182, train mae = 0.00324, test mae = 0.00292
# Epoch = 183, train mae = 0.00326, test mae = 0.00297
# Epoch = 184, train mae = 0.00325, test mae = 0.00291
# Epoch = 185, train mae = 0.00325, test mae = 0.00297
# Epoch = 186, train mae = 0.00326, test mae = 0.00299
# Epoch = 187, train mae = 0.00324, test mae = 0.00291
# Epoch = 188, train mae = 0.00327, test mae = 0.00304
# Epoch = 189, train mae = 0.00325, test mae = 0.00296
# Epoch = 190, train mae = 0.00325, test mae = 0.00296
# Epoch = 191, train mae = 0.00326, test mae = 0.00300
# Epoch = 192, train mae = 0.00326, test mae = 0.00299
# Epoch = 193, train mae = 0.00325, test mae = 0.00298
# Epoch = 194, train mae = 0.00326, test mae = 0.00301
# Epoch = 195, train mae = 0.00326, test mae = 0.00304
# Epoch = 196, train mae = 0.00326, test mae = 0.00303
# Epoch = 197, train mae = 0.00326, test mae = 0.00304
# Epoch = 198, train mae = 0.00326, test mae = 0.00305
# Epoch = 199, train mae = 0.00327, test mae = 0.00306
# Epoch = 200, train mae = 0.00327, test mae = 0.00307
# y_train[0:5], predict_train[0:5]
# [ 0.62225542] [ 0.62510842]
# [ 0.53814403] [ 0.53525126]
# [ 0.76434099] [ 0.76715672]
# [ 0.56802049] [ 0.56871039]
# [ 0.52155909] [ 0.51780069]
# y_test[0:5], predict_test[0:5]
# [ 0.50186924] [ 0.49581501]
# [ 0.69692623] [ 0.69319445]
# [ 0.77651315] [ 0.78065836]
# [ 0.27738522] [ 0.27901924]
# [ 0.59266056] [ 0.59521604]

# %% [markdown]
# ##### Close Session

# %%
sess.close()
